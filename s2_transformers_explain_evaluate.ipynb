# %%
# !pip install -q transformers ferret-xai
# Out:
#      |████████████████████████████████| 4.7 MB 7.6 MB/s
#      |████████████████████████████████| 47 kB 5.5 MB/s
#      |████████████████████████████████| 6.6 MB 38.6 MB/s
#      |████████████████████████████████| 120 kB 59.3 MB/s
#      |████████████████████████████████| 1.4 MB 62.0 MB/s
#      |████████████████████████████████| 365 kB 47.1 MB/s
#      |████████████████████████████████| 569 kB 47.5 MB/s
#      |████████████████████████████████| 1.3 MB 41.1 MB/s
#      |████████████████████████████████| 275 kB 43.4 MB/s
#      |████████████████████████████████| 115 kB 53.6 MB/s
#      |████████████████████████████████| 212 kB 60.2 MB/s
#      |████████████████████████████████| 127 kB 59.1 MB/s
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
from ferret import Benchmark

# %%
# neutral only_r bot
# max
neutral_only_r_bot_tweet_max = "best books for deep learning best books for deep learning, are you seeking resources for deep https://t.co/bbvcbvuct5 #datascience #rstudio #rstats"
# min
neutral_only_r_bot_tweet_min = "unemployment update for the 2 largest eu economies: german unemployment is at 2.8% in jun 2022,  a decrease of -0.1p.p. unemployment in france at 7.2%, flat relative to  prior month #rstats https://t.co/rfryo4kxa5"

# neutral r_py Not_Bot
# max
neutral_r_py_not_bot_tweet_max = "we are #hiring\n☑️like #data #analysis\n☑️ experience w #biological or related #data\n☑️ like engaging w experimentalists\n🔝 coding #rstats &amp; | #python &amp;  stats analyses\n🔅interest in #ml\njob #security🔛 #friendly team🔛#flexible working\n\napply by 26th sep. more details? talk to me https://t.co/8tkscovjbj"
# min
neutral_r_py_not_bot_tweet_min = "6 ways to combat phishing attacks \n#programminglanguages  #machinelearning  #datascience #sql #cybersecurity #bigdata #analytics #ai #iiot #python #rstats #tensorflow #reactjs #cloudcomputing #serverless https://t.co/0yrjspjqri"

# %%
model = AutoModelForSequenceClassification.from_pretrained("cardiffnlp/twitter-xlm-roberta-base-sentiment")
tokenizer = AutoTokenizer.from_pretrained("cardiffnlp/twitter-xlm-roberta-base-sentiment")
classifier = pipeline('text-classification', return_all_scores=True, model=model,tokenizer=tokenizer)
bench = Benchmark(model, tokenizer)
# Out:
# ...
# `return_all_scores` is now deprecated, use `top_k=1` if you want similar functionnality

# %%
neutral_only_r_bot_tweet_max_expl = bench.explain(neutral_only_r_bot_tweet_max, target=1)
bench.show_table(neutral_only_r_bot_tweet_max_expl)
# Out:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# <style type="text/css">
# #T_35aaf_row0_col0, #T_35aaf_row3_col14 {
#   background-color: #e5eaee;
#   color: #000000;
# }
# ...

# %%
neutral_only_r_bot_tweet_max_eval = bench.evaluate_explanations(neutral_only_r_bot_tweet_max_expl, target=1)
bench.show_evaluation_table(neutral_only_r_bot_tweet_max_eval)
# Out:
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_6ce1f_row0_col0, #T_6ce1f_row1_col0 {
#   background-color: #eab0b5;
#   color: #000000;
#   background-color: #a54da5;
#   color: #f1f1f1;
# }
# #T_6ce1f_row0_col1, #T_6ce1f_row5_col1 {
#   background-color: #e1e7ec;
#   color: #000000;
#   background-color: #b46db4;
#   color: #f1f1f1;
# }
# #T_6ce1f_row0_col2 {
#   background-color: #edc9cb;
#   color: #000000;
#   background-color: #ad5dad;
#   color: #f1f1f1;
# }
# #T_6ce1f_row1_col1 {
#   background-color: #dde4ea;
#   color: #000000;
#   background-color: #b36ab3;
#   color: #f1f1f1;
# }
# #T_6ce1f_row1_col2 {
#   background-color: #ebbdc1;
#   color: #000000;
#   background-color: #a956a9;
#   color: #f1f1f1;
# }
# #T_6ce1f_row2_col0 {
#   background-color: #efdbdd;
#   color: #000000;
#   background-color: #b269b2;
#   color: #f1f1f1;
# }
# #T_6ce1f_row2_col1 {
#   background-color: #f2ebeb;
#   color: #000000;
# ...

# %%
neutral_only_r_bot_tweet_min_expl = bench.explain(neutral_only_r_bot_tweet_min, target=1)
bench.show_table(neutral_only_r_bot_tweet_min_expl)
# Out:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# ...

# %%
neutral_only_r_bot_tweet_min_eval = bench.evaluate_explanations(neutral_only_r_bot_tweet_min_expl, target=1)
bench.show_evaluation_table(neutral_only_r_bot_tweet_min_eval)
# Out:
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_04ca1_row0_col0 {
#   background-color: #f0e0e1;
#   color: #000000;
#   background-color: #b46cb4;
#   color: #f1f1f1;
# }
# #T_04ca1_row0_col1 {
#   background-color: #d1dce5;
#   color: #000000;
#   background-color: #af62af;
#   color: #f1f1f1;
# }
# #T_04ca1_row0_col2 {
#   background-color: #f0ddde;
#   color: #000000;
#   background-color: #b36ab3;
#   color: #f1f1f1;
# }
# #T_04ca1_row1_col0 {
#   background-color: #efd4d6;
#   color: #000000;
#   background-color: #b065b0;
#   color: #f1f1f1;
# }
# #T_04ca1_row1_col1 {
#   background-color: #cdd9e3;
#   color: #000000;
#   background-color: #ad5fad;
#   color: #f1f1f1;
# }
# #T_04ca1_row1_col2 {
#   background-color: #ebbcbf;
#   color: #000000;
#   background-color: #a955a9;
#   color: #f1f1f1;
# }
# #T_04ca1_row2_col0, #T_04ca1_row3_col0 {
#   background-color: #f1eaea;
#   color: #000000;
#   background-color: #b773b7;
# ...

# %%
neutral_r_py_not_bot_tweet_max_expl = bench.explain(neutral_r_py_not_bot_tweet_max, target=1)
bench.show_table(neutral_r_py_not_bot_tweet_max_expl)
# Out:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# ...

# %%
neutral_r_py_not_bot_tweet_max_expl_eval = bench.evaluate_explanations(neutral_r_py_not_bot_tweet_max_expl, target=1)
bench.show_evaluation_table(neutral_r_py_not_bot_tweet_max_expl_eval)
# Out:
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_6daf6_row0_col0 {
#   background-color: #eed0d2;
#   color: #000000;
#   background-color: #af62af;
#   color: #f1f1f1;
# }
# #T_6daf6_row0_col1 {
#   background-color: #c7d6e1;
#   color: #000000;
#   background-color: #ac5bac;
#   color: #f1f1f1;
# }
# #T_6daf6_row0_col2 {
#   background-color: #e9a9ae;
#   color: #000000;
#   background-color: #a348a3;
#   color: #f1f1f1;
# }
# #T_6daf6_row1_col0 {
#   background-color: #edcacd;
#   color: #000000;
#   background-color: #ad5ead;
#   color: #f1f1f1;
# }
# #T_6daf6_row1_col1 {
#   background-color: #bfd0dd;
#   color: #000000;
#   background-color: #a956a9;
#   color: #f1f1f1;
# }
# #T_6daf6_row1_col2 {
#   background-color: #e9aeb2;
#   color: #000000;
#   background-color: #a44ba4;
#   color: #f1f1f1;
# }
# #T_6daf6_row2_col0 {
#   background-color: #f0e3e3;
#   color: #000000;
#   background-color: #b56eb5;
#   color: #f1f1f1;
# }
# ...

# %%
neutral_r_py_not_bot_tweet_min_expl = bench.explain(neutral_r_py_not_bot_tweet_min, target=1)
bench.show_table(neutral_r_py_not_bot_tweet_min_expl)
# Out:
# Explainer:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# ...

# %%
neutral_r_py_not_bot_tweet_min_expl_eval = bench.evaluate_explanations(neutral_r_py_not_bot_tweet_min_expl, target=1)
bench.show_evaluation_table(neutral_r_py_not_bot_tweet_min_expl_eval)
# Out:
# Explanation eval:   0%|          | 0/6 [00:00<?, ?it/s]
# <style type="text/css">
# #T_1991c_row0_col0, #T_1991c_row2_col0 {
#   background-color: #f1e5e6;
#   color: #000000;
#   background-color: #b670b6;
#   color: #f1f1f1;
# }
# #T_1991c_row0_col1, #T_1991c_row5_col1 {
#   background-color: #d3dee6;
#   color: #000000;
#   background-color: #b064b0;
#   color: #f1f1f1;
# }
# #T_1991c_row0_col2 {
#   background-color: #f0e1e2;
#   color: #000000;
#   background-color: #b46db4;
#   color: #f1f1f1;
# }
# #T_1991c_row1_col0 {
#   background-color: #edc7ca;
#   color: #000000;
#   background-color: #ac5cac;
#   color: #f1f1f1;
# }
# #T_1991c_row1_col1 {
#   background-color: #cdd9e3;
#   color: #000000;
#   background-color: #ad5fad;
#   color: #f1f1f1;
# }
# #T_1991c_row1_col2 {
#   background-color: #ecbfc2;
#   color: #000000;
#   background-color: #a956a9;
#   color: #f1f1f1;
# }
# #T_1991c_row2_col1 {
#   background-color: #f2f1f1;
#   color: #000000;
# ...
